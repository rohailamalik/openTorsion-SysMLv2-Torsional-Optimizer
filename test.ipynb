# %%
from system import System
from optimizer import Optimizer
import json
from pathlib import Path
from opentorsion.assembly import Assembly
path_to_system_json = "./SysML_System.json"

system = System(path_to_system_json)

# %%
system.plot_assembly()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 system.plot_assembly()
#
# File c:\Data\Research\Doctoral\IFTOMM\iftomm\system.py:61, in System.plot_assembly(self)
#      59 self.plotting = True
#      60 try:
# ---> 61     self.assemble()
#      62 except:
#      63     raise
#
# File c:\Data\Research\Doctoral\IFTOMM\iftomm\system.py:436, in System.assemble(self)
#     433     builder()
#     434     node += 1
# --> 436 self.assembly = Assembly(
#     437     shaft_elements=[e for e in elements if isinstance(e, Shaft)],
#     438     disk_elements=[e for e in elements if isinstance(e, Disk)],
#     439     gear_elements=[e for e in elements if isinstance(e, Gear)]
#     440     )
#
# ...

# %%
vars = system.get_design_vars()
print(vars)
# Out:
# {'Coupling<<>>Choice': <pymoo.core.variable.Choice object at 0x000001B7A62EE510>, 'Propeller_Shaft<<>>Choice': <pymoo.core.variable.Choice object at 0x000001B7D761C690>, 'Propeller_Shaft<<>>length': <pymoo.core.variable.Choice object at 0x000001B7D761C550>, 'Propeller_Shaft<<>>diameter': <pymoo.core.variable.Real object at 0x000001B7D7620BB0>}

# %%
optimizer = Optimizer(system=system, minimize_mask=[False, True], verbose=True)
# Out:
# Coupling<<>>Choice → ['model_A', 'model_B'] <class 'list'>
# Propeller_Shaft<<>>Choice → ['Aluminum', 'Steel'] <class 'list'>
# Propeller_Shaft<<>>length → [0.3, 0.45, 0.6] <class 'list'>

# %%
optimizer.run()
# Out:
# Optimization started...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 optimizer.run()
#
# File c:\Data\Research\Doctoral\IFTOMM\iftomm\optimizer.py:83, in Optimizer.run(self)
#      80 def run(self):
#      82     print("Optimization started...")
# ---> 83     self.result = minimize(
#      84         self.problem, self.algorithm, ("n_gen", self.num_generations), seed=self.random_seed, verbose=self.verbose
#      85         )
#      87     self.final_results = self.problem.final_results
#      88     with open(self.res_path, "w") as f:
#
# File c:\Data\Research\Doctoral\IFTOMM\iftomm\.venv\Lib\site-packages\pymoo\optimize.py:67, in minimize(problem, algorithm, termination, copy_algorithm, copy_termination, **kwargs)
#      64     algorithm.setup(problem, **kwargs)
#      66 # actually execute the algorithm
# ---> 67 res = algorithm.run()
# ...

# %%
system.assemble()
vars = system.get_assembly_json()
print(json.dumps(vars, indent=4))
# Out:
# {
#     "0": {
#         "component": "Motor",
#         "element": "disk",
#         "I": 0.000794,
#         "c": 0.0,
#         "k": 0.0,
#         "speed": 314,
#         "excitation": [
#             [
#                 2959.3802796815853,
#                 100.0
#             ],
#             [
#                 5918.760559363171,
#                 50.0
#             ]
#         ]
#     },
#     "0-1": {
#         "component": "Motor",
#         "element": "shaft",
#         "I": 0.0,
#         "c": 8.08,
#         "k": 190000.0
#     },
#     "1": {
#         "component": "Coupling",
#         "element": "disk",
#         "I": 1.895e-06,
#         "c": 0.0,
#         "k": 0.0,
#         "speed": 314
#     },
#     "1-2": {
#         "component": "Coupling",
#         "element": "shaft",
#         "I": 0.0,
#         "c": 0.29,
#         "k": 6950.0
#     },
#     "2": {
#         "component": "Coupling",
#         "element": "disk",
#         "I": 1.895e-06,
# ...

# %%
print(system.assembly.I)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(system.assembly.I)
#
# AttributeError: 'Assembly' object has no attribute 'I'

# %%
from objective import *
system.assemble()
system.validate()
answer = default_obj_function(system = system)
print(answer)
